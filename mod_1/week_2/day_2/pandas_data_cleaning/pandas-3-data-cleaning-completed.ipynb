# %% [markdown]
# # Data Cleaning with Pandas

# %% [markdown]
# ## Scenario
#
# As data scientists, we want to build a model to predict the sale price of a house in Seattle in 2019, based on its square footage. We know that the King County Department of Assessments has comprehensive data available on real property sales in the Seattle area. We need to prepare the data.

# %%
import pandas as pd

# %% [markdown]
# ### Learning Goals:
#
# - practice cleaning a real dataset
# - practice using `py` files and the terminal in conjunction with jupyter notebooks
# - run a `py` script through the terminal

# %%
# !pwd
# Out:
# /Users/ssadalgekar/Desktop/Chicago-ds-120919/mod_1/week_2/day_2/pandas_data_cleaning

# %% [markdown]
# ### First, get the data!
#
# When working on a project involving data that can fit on our computer, we store it in a `data` directory.
#
# ```bash
# cd <project_directory>  # example: cd ~/flatiron_ds/pandas-3
# mkdir data
# cd data
# ```
#
# Note that `<project_directory>` in angle brackets is a _placeholder_. You should type the path to the actual location on your computer where you're working on this project. Do not literally type `<project_directory>` and _do not type the angle brackets_. You can see an example in the _comment_ to the right of the command above.

# %% [markdown]
# ![terminal](https://media3.giphy.com/media/yR4xZagT71AAM/giphy.gif?cid=790b76115d3620444553533759086a54&rid=giphy.gif)
#
# Now, we'll need to download the two data files that we need. We can do this at the command line:
#
# ```bash
# wget https://aqua.kingcounty.gov/extranet/assessor/Real%20Property%20Sales.zip
# wget https://aqua.kingcounty.gov/extranet/assessor/Residential%20Building.zip
# ```
#
# *Note:* If you do not have the `wget` command yet, you can install it with `brew install wget`, or use `curl <url> -o <filename>`.
#
# Note that `%20` in a URL translates into a space. Even though you will *never put spaces in filenames*, you may need to deal with spaces that _other_ people have used in filenames.
#
# There are two ways to handle the spaces in these filenames when referencing them at the command line.
#
#
# ![internetgif](https://media2.giphy.com/media/QWkuGmMgphvmE/giphy.gif?cid=790b76115d361f42304a6850369f37ea&rid=giphy.gif)

# %% [markdown]
# #### 1. You can _escape_ the spaces by putting a backslash (`\`, remember _backslash is next to backspace_) before each one:
#
# `unzip Real\ Property\ Sales.zip`
#
# This is what happens if you tab-complete the filename in the terminal. Tab completion is your friend!

# %% [markdown]
# #### 2. You can put the entire filename in quotes:
#
# `unzip "Real Property Sales.zip"`
#
# Try unzipping these files with the `unzip` command. The `unzip` command takes one argument, the name of the file that you want to unzip.

# %%
# !pwd
# Out:
# /Users/ssadalgekar/Desktop/Chicago-ds-120919/mod_1/week_2/day_2/pandas_data_cleaning

# %%
sales_df = pd.read_csv('data/EXTR_RPSale.csv')

# %% [markdown]
# ### Seeing pink? Warnings are useful!
#
# Note the warning above: `DtypeWarning: Columns (1, 2) have mixed types.` Because we start with an index of zero, the columns that we're being warned about are actually the _second_ and _third_ columns, `sales_df['Major']` and `sales_df['Minor']`.

# %%
sales_df['Minor'].value_counts()
# Out:
# 20      37016
# 10      36994
# 30      35846
# 40      34889
# 50      33179
# 60      32083
# 70      30461
# 80      29390
# 90      27784
# 100     26672
# 110     25543
# 120     24395
# 130     23022
# 140     22295
# 150     21653
# 160     20790
# 170     19961
# 180     18840
# 190     17784
# 200     17518
# 210     16419
# 220     16050
# 230     15123
# 240     14910
# 250     14437
# 260     13999
# 270     13634
# 280     13275
# 290     12715
# 300     12399
#         ...
# 7622        1
# 1887        1
# 4800        1
# 7533        1
# 2512        1
# 7548        1
# 4380        1
# 7552        1
# 7557        1
# 7970        1
# 1963        1
# 7585        1
# 7608        1
# 3467        1
# 3690        1
# 0373        1
# 7646        1
# 1581        1
# 3631        1
# 7656        1
# 5662        1
# 0786        1
# 3036        1
# 3438        1
# 1392        1
# 7692        1
# 1271        1
# 2143        1
# 7743        1
# 2037        1
# Name: Minor, Length: 11324, dtype: int64

# %%
sales_df.head()
# Out:
#    ExciseTaxNbr   Major Minor DocumentDate  SalePrice    RecordingNbr Volume  \
# 0       1600768  330405   100   03/19/1998     215000  199803251689      145
# 1       2413752  868146    30   09/11/2009          0  20091022001461
# 2       1939480  258190   265   02/06/2003          0  20030214003390
# 3       2999169  919715   200   07/08/2019     192000  20190712001080
# 4       2220242  334330  1343   05/30/2006          0  20060706002163
#
#   Page PlatNbr PlatType  ... PropertyType PrincipalUse SaleInstrument  \
# 0  039  330405        C  ...            2            2              3
# 1                        ...            3            2             15
# 2                        ...            3            6             15
# 3                        ...            3            2              3
# 4                        ...            1            6              3
#
#   AFForestLand  AFCurrentUseLand  AFNonProfitUse  AFHistoricProperty  \
# 0            N                 N               N                   N
# 1            N                 N               N                   N
# 2            N                 N               N                   N
# 3            N                 N               N                   N
# 4            N                 N               N                   N
#
#   SaleReason PropertyClass SaleWarning
# 0          1             3
# 1         11             3    18 31 38
# 2         10             8       31 51
# 3          1             3
# 4         18             7       11 31
#
# [5 rows x 24 columns]

# %%
sales_df['Major'].dtypes
# Out:
# dtype('O')

# %%
sales_df['Minor'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# ### Data overload?
#
# That's a lot of columns. We're only interested in identifying the date, sale price, and square footage of each specific property. What can we do?

# %%
sales_df.columns
# Out:
# Index(['ExciseTaxNbr', 'Major', 'Minor', 'DocumentDate', 'SalePrice',
#        'RecordingNbr', 'Volume', 'Page', 'PlatNbr', 'PlatType', 'PlatLot',
#        'PlatBlock', 'SellerName', 'BuyerName', 'PropertyType', 'PrincipalUse',
#        'SaleInstrument', 'AFForestLand', 'AFCurrentUseLand', 'AFNonProfitUse',
#        'AFHistoricProperty', 'SaleReason', 'PropertyClass', 'SaleWarning'],
#       dtype='object')

# %%
sales_df = sales_df[['Major', 'Minor', 'DocumentDate', 'SalePrice']]

# %%
sales_df.head()
# Out:
#     Major Minor DocumentDate  SalePrice
# 0  330405   100   03/19/1998     215000
# 1  868146    30   09/11/2009          0
# 2  258190   265   02/06/2003          0
# 3  919715   200   07/08/2019     192000
# 4  334330  1343   05/30/2006          0

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2060170 entries, 0 to 2060169
# Data columns (total 4 columns):
# Major           object
# Minor           object
# DocumentDate    object
# SalePrice       int64
# dtypes: int64(1), object(3)
# memory usage: 62.9+ MB

# %%
bldg_df = pd.read_csv('data/EXTR_ResBldg.csv')

# %%
#bldg_df.iloc[:,11]

# %% [markdown]
# ### Another warning! Which column has index 11?

# %%
bldg_df.columns[11]
# Out:
# 'ZipCode'

# %% [markdown]
# `ZipCode` seems like a potentially useful column. We'll need it to determine which house sales took place in Seattle.

# %%
#bldg_df.dtypes

# %% [markdown]
# ### So many features!
#
# As data scientists, we should be _very_ cautious about discarding potentially useful data. But, today, we're interested in _only_ the total square footage of each property. What can we do?

# %%
bldg_df.columns
# Out:
# Index(['Major', 'Minor', 'BldgNbr', 'NbrLivingUnits', 'Address',
#        'BuildingNumber', 'Fraction', 'DirectionPrefix', 'StreetName',
#        'StreetType', 'DirectionSuffix', 'ZipCode', 'Stories', 'BldgGrade',
#        'BldgGradeVar', 'SqFt1stFloor', 'SqFtHalfFloor', 'SqFt2ndFloor',
#        'SqFtUpperFloor', 'SqFtUnfinFull', 'SqFtUnfinHalf', 'SqFtTotLiving',
#        'SqFtTotBasement', 'SqFtFinBasement', 'FinBasementGrade',
#        'SqFtGarageBasement', 'SqFtGarageAttached', 'DaylightBasement',
#        'SqFtOpenPorch', 'SqFtEnclosedPorch', 'SqFtDeck', 'HeatSystem',
#        'HeatSource', 'BrickStone', 'ViewUtilization', 'Bedrooms',
#        'BathHalfCount', 'Bath3qtrCount', 'BathFullCount', 'FpSingleStory',
#        'FpMultiStory', 'FpFreestanding', 'FpAdditional', 'YrBuilt',
#        'YrRenovated', 'PcntComplete', 'Obsolescence', 'PcntNetCondition',
#        'Condition', 'AddnlCost'],
#       dtype='object')

# %%
bldg_df = bldg_df[['Major', 'Minor', 'SqFtTotLiving', 'ZipCode']]

# %%
bldg_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 514563 entries, 0 to 514562
# Data columns (total 4 columns):
# Major            514563 non-null int64
# Minor            514563 non-null int64
# SqFtTotLiving    514563 non-null int64
# ZipCode          468849 non-null object
# dtypes: int64(3), object(1)
# memory usage: 15.7+ MB

# %%
sales_data = pd.merge(sales_df, bldg_df, on = ['Major','Minor'])

# %% [markdown]
# ### Error!
#
# Why are we seeing an error when we try to join the dataframes?
#
# <table>
#     <tr>
#         <td style="text-align:left"><pre>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2013160 entries, 0 to 2013159
# Data columns (total 4 columns):
# Major           object
# Minor           object
# DocumentDate    object
# SalePrice       int64
# dtypes: int64(1), object(3)
# memory usage: 61.4+ MB</pre></td>
#         <td style="text-align:left"><pre>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 511359 entries, 0 to 511358
# Data columns (total 4 columns):
# Major            511359 non-null int64
# Minor            511359 non-null int64
# SqFtTotLiving    511359 non-null int64
# ZipCode          468345 non-null object
# dtypes: int64(3), object(1)
# memory usage: 15.6+ MB
# </pre></td>
#     </tr>
# </table>
#
# Review the error message in light of the above:
#
# * `ValueError: You are trying to merge on object and int64 columns.`

# %% [markdown]
# ### Error!
#
# Note the useful error message above:
#
# `ValueError: Unable to parse string "      " at position 936643`
#
# In this case, we want to treat non-numeric values as missing values. Let's see if there's a way to change how the `pd.to_numeric` function handles errors.

# %%
# The single question mark means "show me the docstring"
pd.to_numeric?

# %% [markdown]
# Here's the part that we're looking for:
# ```
# errors : {'ignore', 'raise', 'coerce'}, default 'raise'
#     - If 'raise', then invalid parsing will raise an exception
#     - If 'coerce', then invalid parsing will be set as NaN
#     - If 'ignore', then invalid parsing will return the input
# ```
#
# Let's try setting the `errors` parameter to `'coerce'`.

# %%
sales_df['Major'] = pd.to_numeric(sales_df['Major'], errors ='coerce')

sales_df['Major'].dtypes
# Out:
# dtype('float64')

# %%
sales_df.isnull().sum()
# Out:
# Major           2
# Minor           0
# DocumentDate    0
# SalePrice       0
# dtype: int64

# %%
sales_df.isna().sum()
# Out:
# Major           2
# Minor           0
# DocumentDate    0
# SalePrice       0
# dtype: int64

# %% [markdown]
# Did it work?

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2060170 entries, 0 to 2060169
# Data columns (total 4 columns):
# Major           float64
# Minor           object
# DocumentDate    object
# SalePrice       int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 62.9+ MB

# %% [markdown]
# It worked! Let's do the same thing with the `Minor` parcel number.

# %%
sales_df['Minor'] = pd.to_numeric(sales_df['Minor'], errors='coerce')

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2060170 entries, 0 to 2060169
# Data columns (total 4 columns):
# Major           float64
# Minor           float64
# DocumentDate    object
# SalePrice       int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 62.9+ MB

# %% [markdown]
# Now, let's try our join again.

# %%
sales_data = pd.merge(sales_df, bldg_df, on=['Major', 'Minor'])

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1472252 entries, 0 to 1472251
# Data columns (total 6 columns):
# Major            1472252 non-null float64
# Minor            1472252 non-null float64
# DocumentDate     1472252 non-null object
# SalePrice        1472252 non-null int64
# SqFtTotLiving    1472252 non-null int64
# ZipCode          1349058 non-null object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 78.6+ MB

# %%
sales_data.isna().sum()
# Out:
# Major                 0
# Minor                 0
# DocumentDate          0
# SalePrice             0
# SqFtTotLiving         0
# ZipCode          123194
# dtype: int64

# %% [markdown]
# We can see right away that we're missing zip codes for many of the sales transactions. (1321536 non-null entries for ZipCode is fewer than the 1436772 entries in the dataframe.)

# %%
sales_data.loc[sales_data['ZipCode'].isna()].head()
# Out:
#       Major   Minor DocumentDate  SalePrice  SqFtTotLiving ZipCode
# 4  334330.0  1343.0   05/30/2006          0           4600     NaN
# 5  334330.0  1343.0   05/30/2006          0           4600     NaN
# 6  334330.0  1343.0   11/26/2001          0           4600     NaN
# 7  334330.0  1343.0   05/30/2006          0           4600     NaN
# 8  334330.0  1343.0   06/30/2016          0           4600     NaN

# %% [markdown]
# Because we are interested in finding houses in Seattle zip codes, we will need to drop the rows with missing zip codes.

# %%
# sales_data.head()
sales_data = sales_data.loc[~sales_data['ZipCode'].isna(),:]

# %%
# 1334823 homes
sales_data.shape
# Out:
# (1349058, 6)

# %% [markdown]
# # Your turn: Data Cleaning with Pandas
# ![turtletype](https://media3.giphy.com/media/cFdHXXm5GhJsc/giphy.gif?cid=790b76115d3627d8354c7179366b0672&rid=giphy.gif)

# %% [markdown]
# # 311 Service Requests received by the City of Chicago
# https://data.cityofchicago.org/Service-Requests/311-Service-Requests/v6vf-nfxy
#
#
#
# ###  Read and Investigate data
# Use multiple notebook cells to accomplish this! Press `[esc]` then `B` to create a new cell below the current cell. Press `[return]` to start typing in the new cell.

# %%
df = pd.read_csv('/Users/ssadalgekar/Desktop/311_Service_Requests.csv')

# %%
df.head()
# Out:
#        SR_NUMBER                           SR_TYPE SR_SHORT_CODE  \
# 0  SR19-01209420  Sewer Cave-In Inspection Request           AAD
# 1  SR19-01141794       Pothole in Street Complaint           PHF
# 2  SR19-01170443       Pothole in Street Complaint           PHF
# 3  SR19-01195829       Pothole in Street Complaint           PHF
# 4  SR19-01193910       Pothole in Street Complaint           PHF
#
#                        OWNER_DEPARTMENT     STATUS            CREATED_DATE  \
# 0  DWM - Department of Water Management  Completed  03/23/2019 12:29:06 PM
# 1   CDOT - Department of Transportation  Completed  03/12/2019 12:02:21 AM
# 2   CDOT - Department of Transportation  Completed  03/16/2019 12:30:20 PM
# 3   CDOT - Department of Transportation  Completed  03/20/2019 10:34:41 PM
# 4   CDOT - Department of Transportation       Open  03/20/2019 03:13:16 PM
#
#        LAST_MODIFIED_DATE             CLOSED_DATE       STREET_ADDRESS CITY  \
# 0  06/24/2019 11:44:57 PM  06/24/2019 11:44:57 PM         1800 N maude  NaN
# 1  11/18/2019 10:19:43 AM  11/18/2019 10:19:43 AM                  NaN  NaN
# 2  10/17/2019 05:12:48 PM  10/17/2019 05:12:48 PM                  NaN  NaN
# 3  11/04/2019 08:52:35 AM  11/04/2019 08:52:35 AM     1600 N MARCEY ST  NaN
# 4  03/20/2019 07:30:18 PM                     NaN  10733 S Beverly AVE  NaN
#
#    ... PRECINCT SANITATION_DIVISION_DAYS CREATED_HOUR CREATED_DAY_OF_WEEK  \
# 0  ...      NaN                      NaN           12                   7
# 1  ...      NaN                      NaN            0                   3
# 2  ...      NaN                      NaN           12                   7
# 3  ...      NaN                      NaN           22                   4
# 4  ...      NaN                      NaN           15                   4
#
#   CREATED_MONTH X_COORDINATE  Y_COORDINATE  LATITUDE LONGITUDE LOCATION
# 0             3          NaN           NaN       NaN       NaN      NaN
# 1             3          NaN           NaN       NaN       NaN      NaN
# 2             3          NaN           NaN       NaN       NaN      NaN
# 3             3          NaN           NaN       NaN       NaN      NaN
# 4             3          NaN           NaN       NaN       NaN      NaN
#
# [5 rows x 37 columns]

# %% [markdown]
# ##### Create new df with the following columns:
#     'SR_NUMBER', 'SR_TYPE', 'SR_SHORT_CODE', 'OWNER_DEPARTMENT', 'STATUS',
#        'CREATED_DATE', 'LAST_MODIFIED_DATE', 'LOCATION','CITY', 'LATITUDE']]

# %%
df = df[['SR_NUMBER', 'SR_TYPE', 'SR_SHORT_CODE', 'OWNER_DEPARTMENT', 'STATUS',
   'CREATED_DATE', 'LAST_MODIFIED_DATE', 'LOCATION','CITY', 'LATITUDE']]

df.head()
# Out:
#        SR_NUMBER                           SR_TYPE SR_SHORT_CODE  \
# 0  SR19-01209420  Sewer Cave-In Inspection Request           AAD
# 1  SR19-01141794       Pothole in Street Complaint           PHF
# 2  SR19-01170443       Pothole in Street Complaint           PHF
# 3  SR19-01195829       Pothole in Street Complaint           PHF
# 4  SR19-01193910       Pothole in Street Complaint           PHF
#
#                        OWNER_DEPARTMENT     STATUS            CREATED_DATE  \
# 0  DWM - Department of Water Management  Completed  03/23/2019 12:29:06 PM
# 1   CDOT - Department of Transportation  Completed  03/12/2019 12:02:21 AM
# 2   CDOT - Department of Transportation  Completed  03/16/2019 12:30:20 PM
# 3   CDOT - Department of Transportation  Completed  03/20/2019 10:34:41 PM
# 4   CDOT - Department of Transportation       Open  03/20/2019 03:13:16 PM
#
#        LAST_MODIFIED_DATE LOCATION CITY  LATITUDE
# 0  06/24/2019 11:44:57 PM      NaN  NaN       NaN
# 1  11/18/2019 10:19:43 AM      NaN  NaN       NaN
# 2  10/17/2019 05:12:48 PM      NaN  NaN       NaN
# 3  11/04/2019 08:52:35 AM      NaN  NaN       NaN
# 4  03/20/2019 07:30:18 PM      NaN  NaN       NaN

# %%
df['CITY'].value_counts()
# Out:
# Chicago              708898
# CHICAGO              421789
# Arlington Heights         1
# ST                        1
# Name: CITY, dtype: int64

# %% [markdown]
# ### Investigate and handle missing values
#
# What's the right thing to do with missing values?

# %%
df.isna().sum()
# Out:
# SR_NUMBER                   0
# SR_TYPE                     0
# SR_SHORT_CODE               0
# OWNER_DEPARTMENT            0
# STATUS                      0
# CREATED_DATE                0
# LAST_MODIFIED_DATE          0
# LOCATION                24754
# CITY                  1093257
# LATITUDE                24754
# dtype: int64

# %%
city_df = df.dropna(how = 'any', subset = ['LOCATION'])

# %%
city_df.drop('LOCATION', axis = 1, inplace =True)

# %%
city_df.head()
# Out:
#          SR_NUMBER                           SR_TYPE SR_SHORT_CODE  \
# 11   SR19-02763102  Sewer Cave-In Inspection Request           AAD
# 171  SR19-02366062         311 INFORMATION ONLY CALL        311IOC
# 175  SR19-02366112          Aircraft Noise Complaint           AVN
# 205  SR19-01480551       Pothole in Street Complaint           PHF
# 586  SR19-02763151         311 INFORMATION ONLY CALL        311IOC
#
#                          OWNER_DEPARTMENT     STATUS            CREATED_DATE  \
# 11   DWM - Department of Water Management  Completed  10/19/2019 03:31:55 PM
# 171                     311 City Services  Completed  09/02/2019 07:55:43 AM
# 175                              Aviation  Completed  09/02/2019 08:11:53 AM
# 205   CDOT - Department of Transportation  Completed  05/13/2019 12:59:56 PM
# 586                     311 City Services  Completed  10/19/2019 03:42:07 PM
#
#          LAST_MODIFIED_DATE     CITY   LATITUDE
# 11   11/25/2019 01:34:43 PM      NaN  41.966001
# 171  09/02/2019 08:30:32 AM  Chicago  41.871831
# 175  09/02/2019 08:30:51 AM  Chicago  41.994897
# 205  11/02/2019 08:01:21 AM      NaN  41.742149
# 586  10/19/2019 04:31:37 PM  Chicago  41.953736

# %%
#Filling missing/NAN city with Chicago
city_df['CITY'].fillna('Chicago', axis = 0, inplace=True)

# %%
#filling NA values for lattitude with it's mean
city_df.LATITUDE.fillna(city_df.LATITUDE.mean(), inplace= True)

# %%
city_df.CITY.value_counts()
# Out:
# Chicago    2199192
# Name: CITY, dtype: int64

# %%
city_df['CITY'] = city_df['CITY'].str.title()
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
#another way
#new = {'St':'Chicago'}
#city_df['CITY']= city_df['CITY'].map(new)

# %%
city_df['CITY'].dtypes
# Out:
# dtype('O')

# %%
city_df.CITY.replace('St', 'Chicago', inplace = True)
# Out:
# //anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:6586: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %% [markdown]
# ### Find out top 3 service types

# %%
#top 3 service types people complaint about 
city_df.SR_TYPE.value_counts().head(3)
# Out:
# Snow Removal - Protected Bike Lane or Bridge Sidewalk    11
# Inaccurate Retail Scales Complaint                        8
# Petcoke Dust Complaint                                    5
# Smokeless Tobacco at Sports Event Complaint               5
# Licensed Pharmaceutical Representative Complaint          4
# Name: SR_TYPE, dtype: int64

# %%
#least 3 service types
city_df.SR_TYPE.value_counts().tail(3)
# Out:
# Petcoke Dust Complaint                              5
# Smokeless Tobacco at Sports Event Complaint         5
# Licensed Pharmaceutical Representative Complaint    4
# Name: SR_TYPE, dtype: int64

# %%
city_df.shape
# Out:
# (2199192, 9)

# %%
#number of duplicate rows in whole df
city_df.duplicated().sum()
# Out:
# 0

# %%
#subsetting rows with duplicate rows
city_df[city_df.duplicated()]   #Empty as no duplicate rows
# Out:
# Empty DataFrame
# Columns: [SR_NUMBER, SR_TYPE, SR_SHORT_CODE, OWNER_DEPARTMENT, STATUS, CREATED_DATE, LAST_MODIFIED_DATE, CITY, LATITUDE]
# Index: []

# %%
#duplicate rows for certain columns
city_df[city_df.duplicated(subset =['SR_SHORT_CODE','STATUS'], keep ='last')]
# Out:
#              SR_NUMBER                                SR_TYPE SR_SHORT_CODE  \
# 11       SR19-02763102       Sewer Cave-In Inspection Request           AAD
# 171      SR19-02366062              311 INFORMATION ONLY CALL        311IOC
# 175      SR19-02366112               Aircraft Noise Complaint           AVN
# 205      SR19-01480551            Pothole in Street Complaint           PHF
# 586      SR19-02763151              311 INFORMATION ONLY CALL        311IOC
# 601      SR19-02365602               Aircraft Noise Complaint           AVN
# 610      SR19-02189834               Garbage Cart Maintenance           SIE
# 8242     SR19-03045364               Aircraft Noise Complaint           AVN
# 10008    SR19-03045392               Aircraft Noise Complaint           AVN
# 11379    SR19-02189957               Aircraft Noise Complaint           AVN
# 11452    SR19-02763158              311 INFORMATION ONLY CALL        311IOC
# 11489    SR19-03045406               Aircraft Noise Complaint           AVN
# 17593    SR19-02763168               Garbage Cart Maintenance           SIE
# 17660    SR19-03045423               Aircraft Noise Complaint           AVN
# 18807    SR19-02920403               Aircraft Noise Complaint           AVN
# 19134    SR19-02763185               Graffiti Removal Request          GRAF
# 19138    SR19-02763190                   Tree Removal Request           SEE
# 19154    SR19-02763189    Vacant/Abandoned Building Complaint           BBK
# 19206    SR19-02657400                Street Cleaning Request           SDP
# 19314    SR19-02763200           Tree Debris Clean-Up Request           SEL
# 19320    SR19-02920428               Aircraft Noise Complaint           AVN
# 19801    SR19-02763230               Garbage Cart Maintenance           SIE
# 19803    SR19-02763227                   Restaurant Complaint           HFB
# 19890    SR19-02763236            Dead Animal Pick-Up Request           SGQ
# 19994    SR19-02763241           Rodent Baiting/Rat Complaint           SGA
# 20019    SR19-02763252                Alley Pothole Complaint           PHB
# 20111    SR19-02920485              311 INFORMATION ONLY CALL        311IOC
# 21046    SR19-02763263              311 INFORMATION ONLY CALL        311IOC
# 21497    SR19-02920498               Aircraft Noise Complaint           AVN
# 21540    SR19-01954774              311 INFORMATION ONLY CALL        311IOC
# ...                ...                                    ...           ...
# 2223898  SR19-03117595               Graffiti Removal Request          GRAF
# 2223901  SR19-03117162              311 INFORMATION ONLY CALL        311IOC
# 2223902  SR19-03117474  Sign Repair Request - All Other Signs           PCE
# 2223935  12/11/2019 10:57:18 AM  12/11/2019 11:30:24 AM  Chicago  41.871831
# 2223936  12/11/2019 11:54:04 AM  12/11/2019 11:54:13 AM  Chicago  41.904980
# 2223937  12/11/2019 10:51:51 AM  12/11/2019 11:30:24 AM  Chicago  41.871831
# 2223938  12/11/2019 11:04:02 AM  12/11/2019 11:30:45 AM  Chicago  41.871831
# 2223940  12/11/2019 10:35:46 AM  12/11/2019 11:30:24 AM  Chicago  41.871831
# 2223941  12/11/2019 11:12:50 AM  12/11/2019 11:31:33 AM  Chicago  41.871831
#
# [2198948 rows x 9 columns]

# %%
city_df.SR_SHORT_CODE.duplicated().sum()
# Out:
# 2199096

# %%
#dropping dupliates based on SR_TYPE keeping the first instance

city_df.drop_duplicates(subset= ['SR_TYPE'],keep = 'first')
# Out:
#              SR_NUMBER                                            SR_TYPE  \
# 11       SR19-02763102                   Sewer Cave-In Inspection Request
# 171      SR19-02366062                          311 INFORMATION ONLY CALL
# 175      SR19-02366112                           Aircraft Noise Complaint
# 205      SR19-01480551                        Pothole in Street Complaint
# 610      SR19-02189834                           Garbage Cart Maintenance
# 19134    SR19-02763185                           Graffiti Removal Request
# 19138    SR19-02763190                               Tree Removal Request
# 19154    SR19-02763189                Vacant/Abandoned Building Complaint
# 19206    SR19-02657400                            Street Cleaning Request
# 19314    SR19-02763200                       Tree Debris Clean-Up Request
# 19803    SR19-02763227                               Restaurant Complaint
# 19890    SR19-02763236                        Dead Animal Pick-Up Request
# 19994    SR19-02763241                       Rodent Baiting/Rat Complaint
# 20019    SR19-02763252                            Alley Pothole Complaint
# 21594    SR19-02365489                          Alley Light Out Complaint
# 21604    SR19-03118194                        Abandoned Vehicle Complaint
# 21621    SR19-02365490                    Sign Repair Request - Stop Sign
# 21661    SR19-02763295                                  Tree Trim Request
# 21668    SR19-02365498              Sign Repair Request - All Other Signs
# 21695    SR19-02763500                         Street Light Out Complaint
# 21707    SR19-01622184                        Water in Basement Complaint
# 21708    SR19-01622170                           Clean Vacant Lot Request
# 21712    SR19-00109655                  Sewer Cleaning Inspection Request
# 21717    SR19-02365523                 Sign Repair Request - One Way Sign
# 21722    SR19-01622207                          Water On Street Complaint
# 21725    SR19-01622609                         Yard Waste Pick-Up Request
# 21732    SR19-01622606                              Fly Dumping Complaint
# 21734    SR19-01622240                               Weed Removal Request
# 21737    SR19-01622658                                 Building Violation
# 21750    SR19-01622700                       Traffic Signal Out Complaint
# ...                ...                                                ...
# 24858    SR19-01683408                                          Dead Bird
# 27677    SR19-01625331                           Animal In Trap Complaint
# 27828    SR19-02030996                       Low Water Pressure Complaint
# 28738    SR19-01234900                    Clean and Green Program Request
# 29073    SR19-01745734                                          E-Scooter
# 29114    SR19-01684597                     Inaccurate Fuel Pump Complaint
# 29134    SR19-01626003                 Tobacco - Sale to Minors Complaint
# 29316    SR19-01684515                       Coyote Interaction Complaint
# 29367    SR19-02031149                            Sidewalk Cafe Complaint
# 30254    SR19-01626643                     Liquor Establishment Complaint
# 30457    SR19-01324013                Pavement Cave-In Inspection Request
# 1146563  Completed  12/20/2018 01:24:52 AM  05/16/2019 04:31:50 PM  Chicago
# 1190349  Completed  01/04/2019 10:10:32 PM  05/16/2019 04:51:46 PM  Chicago
# 2167999   Canceled  09/05/2019 02:24:05 PM  09/05/2019 02:29:45 PM  Chicago
#
#           LATITUDE
# 11       41.966001
# 171      41.871831
# 175      41.994897
# 205      41.742149
# 610      41.781961
# 19134    41.943369
# 19138    41.895672
# 19154    41.777476
# 19206    41.971530
# 19314    41.717366
# 19803    41.889820
# 19890    41.854546
# 19994    41.947342
# 20019    41.977078
# 21594    41.762659
# 21604    41.961456
# 21621    41.864437
# 21661    41.928294
# 21668    41.864579
# 21695    41.755082
# 21707    41.685571
# 21708    41.927866
# 21712    41.792941
# 21717    41.864413
# 21722    41.799932
# 21725    41.935721
# 21732    41.735767
# 21734    41.678562
# 21737    41.904417
# 21750    41.898695
# ...            ...
# 24858    41.878141
# 27677    41.921066
# 27828    41.986775
# 28738    41.765587
# 29073    41.898213
# 29114    41.692781
# 29134    41.721900
# 29316    41.785861
# 29367    41.882211
# 30254    41.864979
# 30457    41.792283
# 30731    41.889445
# 31224    41.744287
# 31510    41.759253
# 33258    41.691118
# 33350    41.791318
# 40334    41.758426
# 41604    41.960427
# 42993    41.728341
# 50767    41.728862
# 61470    41.730679
# 73010    41.971245
# 156123   41.974042
# 259704   41.885934
# 270443   41.793899
# 410833   41.943192
# 653602   41.896577
# 1146563  41.728969
# 1190349  41.990126
# 2167999  41.912952
#
# [96 rows x 9 columns]

# %%
#unique SR_TYPE

city_df.SR_TYPE.unique()
# Out:
# array(['Sewer Cave-In Inspection Request', '311 INFORMATION ONLY CALL',
#        'Aircraft Noise Complaint', 'Pothole in Street Complaint',
#        'Garbage Cart Maintenance', 'Graffiti Removal Request',
#        'Tree Removal Request', 'Vacant/Abandoned Building Complaint',
#        'Street Cleaning Request', 'Tree Debris Clean-Up Request',
#        'Restaurant Complaint', 'Dead Animal Pick-Up Request',
#        'Rodent Baiting/Rat Complaint', 'Alley Pothole Complaint',
#        'Alley Light Out Complaint', 'Abandoned Vehicle Complaint',
#        'Sign Repair Request - Stop Sign', 'Tree Trim Request',
#        'Sign Repair Request - All Other Signs',
#        'Street Light Out Complaint', 'Water in Basement Complaint',
#        'Clean Vacant Lot Request', 'Sewer Cleaning Inspection Request',
#        'Sign Repair Request - One Way Sign', 'Water On Street Complaint',
#        'Yard Waste Pick-Up Request', 'Fly Dumping Complaint',
#        'Weed Removal Request', 'Building Violation',
#        'Traffic Signal Out Complaint', 'Water Quality Concern',
#        'Missed Garbage Pick-Up Complaint',
#        'No Building Permit and Construction Violation',
#        'Vicious Animal Complaint', 'Cab Feedback',
#        'Open Fire Hydrant Complaint', 'Sanitation Code Violation',
#        'Nuisance Animal Complaint', 'Stray Animal Complaint',
#        'Operating Without Business License Complaint',
#        'Sidewalk Inspection Request', 'Consumer Fraud Complaint',
#        'Tree Planting Request', 'Alley Sewer Inspection Request',
#        'Street Light Pole Damage Complaint',
#        'Street Light Pole Door Missing Complaint', 'No Water Complaint',
#        'Wire Basket Request', 'Sign Repair Request - Do Not Enter Sign',
#        'Paid Sick Leave Violation', 'Consumer Retail Store Complaint',
#        'Pushcart Food Vendor Complaint', 'Fire Safety Inspection Request',
#        'Vehicle Parked in Bike Lane Complaint',
#        'Pet Wellness Check Request', 'Report an Injured Animal',
#        'Street Light On During Day Complaint',
#        'Public Vehicle/Valet Complaint',
#        'Renters and Foreclosure Complaint',
#        'Home Buyer Program Info Request', 'Bicycle Request/Complaint',
#        'Recycling Inspection Request', 'Lead Inspection Request',
#        'City Vehicle Sticker Violation',
#        'Shared Housing/Vacation Rental Complaint',
#        'Viaduct Light Out Complaint', 'Dead Bird',
#        'Animal In Trap Complaint', 'Low Water Pressure Complaint',
#        'Clean and Green Program Request', 'E-Scooter',
#        'Inaccurate Fuel Pump Complaint',
#        'Tobacco - Sale to Minors Complaint',
#        'Coyote Interaction Complaint', 'Sidewalk Cafe Complaint',
#        'Liquor Establishment Complaint',
#        'Pavement Cave-In Inspection Request',
#        'Tobacco - General Complaint',
#        'Bungalow Rehab/Purchase Information Request',
#        'Outdated Merchandise Complaint', 'Extreme Weather Notification',
#        'Porch Inspection Request', 'Minimum Wage Complaint',
#        'Bee/Wasp Removal', 'Ridesharing Complaint', 'Cable TV Complaint',
#        'Ice and Snow Removal Request',
#        'Snow - Object/Dibs Removal Request', 'No Solicitation Complaint',
#        'Inaccurate Retail Scales Complaint',
#        'Smokeless Tobacco at Sports Event Complaint',
#        'Snow – Uncleared Sidewalk Complaint',
#        'Protected Bike Lane - Debris Removal', 'Petcoke Dust Complaint',
#        'Licensed Pharmaceutical Representative Complaint',
#        'Snow Removal - Protected Bike Lane or Bridge Sidewalk'],
#       dtype=object)

# %%
# number of unique SR_TYPE
city_df.SR_TYPE.nunique()
# Out:
# 96

# %% [markdown]
# ## Pair Programming:
#
# For these exercises, we will be practicing pair programming.
# While we work through these exercises, choose who will code and who will supervise.
# I.E., one person types, and the other suggests the appropriate direction to head in.

# %% [markdown]
# ### In-class Exercise:
# Think about 2 questions each person and use city_df to answer your questions

# %% [markdown]
# ## After class :
# ### Turning code into a script
#
# #### make a new .py file
# - open a new `.py` file _or_ open a new jupyter notbook and export as a `.py` file so we can start to edit the `.py` file directly
# - save the file as `mean_ppsf_seattle.py`
# - look at all your code between `sales_df = pd.read_csv('data/Real Property Sales.zip')` and question `number 6` above
#
# #### review & organize your code
# - _organize_ your code in the `mean_ppsf_seattle.py` to start with `sales_df = pd.read_csv('data/Real Property Sales.zip')` and end with printing out the mean price per square foot for a house sold in seattle in 2019
# - the code should be able to run without throwing any errors
# - remember to include `import pandas as pd` and any other necessary statements at the start of your script
#
# #### test your script
# - go to the terminal
# - make sure you are in the same directory path as your jupyter notebook and the `.py` file
# - in the terminal type and then run `python mean_ppsf_seattle.py`
# - confirm the script returns in terminal what you wanted it to return
#
#
# ![anykey](https://media2.giphy.com/media/26BGIqWh2R1fi6JDa/giphy.gif?cid=790b76115d3627d8354c7179366b0672&rid=giphy.gif)
